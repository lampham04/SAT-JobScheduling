# %%
import pandas as pd

# %%
def read_filenames(xls_path, sheetname, instance_type):
    df = pd.read_excel(xls_path, sheet_name=sheetname, engine="xlrd")

    # normalize column names
    df.columns = [c.strip() for c in df.columns]

    # keep valid OPT values
    df["OPT VALUE"] = pd.to_numeric(df["OPT VALUE"], errors="coerce")

    df = df[
        (df["OPT VALUE"].notna()) &
        (df["PT"] == instance_type)
    ]

    filenames = df["filename"].astype(str).tolist()
    return df, filenames

# %%
XLS_PATH = "./data/results/Results30-40-50.xls"
SHEET_NAME = "50 jobs"
INSTANCE_TYPE = "S"

# %%
df_filtered, filenames = read_filenames(XLS_PATH, SHEET_NAME, INSTANCE_TYPE)

sat_df = pd.read_excel("./data/results/results_Lmax_incremental_SAT.csv")
sat_result = sat_df['OUR OPT VALUE']

sat_result
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 df_filtered, filenames = read_filenames(XLS_PATH, SHEET_NAME, INSTANCE_TYPE)
# ----> 3 sat_df = pd.read_excel("./data/results/results_Lmax_incremental_SAT.xls", engine="xlrd")
#       4 sat_result = sat_df['OUR OPT VALUE']
#       6 sat_result
#
# File c:\Users\LamPham\Desktop\Lab\.venv_38\lib\site-packages\pandas\io\excel\_base.py:478, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476 if not isinstance(io, ExcelFile):
#     477     should_close = True
# --> 478     io = ExcelFile(io, storage_options=storage_options, engine=engine)
# ...

# %%
row = {
            "filename": fname,
            #"OPT VALUE": opt_dict.get(fname),
            "OPT VALUE": our_ub,
            "STATUS": status,
            "TIME (s)": round(elapsed, 2)
        }

        pd.DataFrame([row]).to_csv(
            RESULT_CSV,
            mode="a",
            header=not csv_exists,
            index=False
        )
